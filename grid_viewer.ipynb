# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
arr = np.loadtxt("grid.csv", delimiter=',')
fig, ax = plt.subplots(figsize=(40,20))
im = ax.imshow(arr)
fig.colorbar(im)
plt.show()

# %%
arr = np.loadtxt("fft.csv", delimiter=',')
fig, ax = plt.subplots(figsize=(40,20))
im = ax.imshow(arr)
fig.colorbar(im)
plt.show()

# %%
arr = np.loadtxt("fft.csv", delimiter=',')
fig, ax = plt.subplots(figsize=(40,20))
im = ax.imshow(arr)
fig.colorbar(im)
plt.show()

# %%
np.log2(8).astype(int)
# Out:
# np.int64(3)
